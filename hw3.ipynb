# %%
from math import cos as c
from math import sin as s

t1 = 0.6
t12 = 0.6+t1
t123 = 0.4+t12

print(-s(t1))
print(-s(t12))
print(-s(t123))
print()
print(c(t1))
print(c(t12))
print(c(t123))
# Out:
# -0.5646424733950354
# -0.9320390859672263
# -0.9995736030415051
#
# 0.8253356149096783
# 0.3623577544766736
# -0.029199522301288815
